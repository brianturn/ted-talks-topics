# %%
import pickle
import pandas as pd

# %%
# with open('corpus_final.pkl', 'rb') as picklefile:
#     df = pickle.load(picklefile)

# %%
from textblob import TextBlob #sentiment analysis using TextBlob

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# df.sort_values(by='views', ascending=False)

# %% [markdown]
# ### Map Hans Rosling's sentiment analysis to dataframe and visualize in matplotlib

# %%
hans = df.loc[2449].text.split('.')

# %%
hans_sentiments = []
for item in hans:
    hans_sentiment = TextBlob(item).sentiment
    hans_sentiments.append(hans_sentiment)
    
df_hans = pd.DataFrame(hans_sentiments)
df_hans['text'] = hans

# %%
# fig = plt.figure(figsize=(20,10))

# plt.plot(df_hans['polarity'], color='black')
# plt.fill_between(df_hans['index'],0, df_hans['polarity'], color='r')

# plt.xlabel('Sentences', fontsize=18, fontweight = 'bold')
# plt.ylabel('Polarity', fontsize=18, fontweight= 'bold')
# plt.tick_params(labelsize=16)
# plt.savefig("sentiment_analysis.png");

# %% [markdown]
# ### Write out Hans' sentiments to CSV file for D3 viz

# %%
df_hans_csv = df_hans.drop(['index', 'subjectivity', 'text'], axis=1)

# %%
df_hans_csv.to_csv('sentiment.csv', sep=',')
